# %%
def greet(lang):
  if lang == 'es':
    return 'Hola'
  elif lang == 'fr':
    return 'Bonjour'
  else:
    return 'Hello'

# %%
print(greet('es'), 'Sally')
# Out:
# Hola Sally

# %%
def addtwo(a,b):
  return a+b

# %%
print(addtwo(4,5))
# Out:
# 9

# %%
def triangle_perimeter(side1, side2, side3):
  '''(number, number, number) -> number

  Return the perimeter of a triangle with sides of length
  side1, side2, side3.

  >>> triangle_perimeter(3, 4, 5)
  12
  >>> triangle_perimeter(10.5, 6, 9,3)
  25.8  
  '''
  return (side1 + side2 + side3)

# %%
def triangle_semiperimeter(side1, side2, side3):
  '''(number, number, number) -> float

  Return the semi-perimeter of a triangle with sides of length
  side1, side2, side3.

  >>> triangle_semiperimeter(3, 4, 5)
  6.0
  >>> triangle_semiperimeter(10.5, 6, 9.3)
  12.9
  '''
  return triangle_perimeter(side1, side2, side3)/2

# %%
_list = [3, 41, 12, 9, 74, 15]

i = -1

for num in _list:
  if i<num: i = num
print('Largest number is ',i)
# Out:
# Largest number is  74

# %%
count = 0
for num in _list:
  count += 1
print(count)
# Out:
# 6

# %%
sum = 0
for num in _list:
  sum = sum+num
print(sum)
# Out:
# 154

# %%
_list = [3, 41, 12, 9, 74, 15]
count = 0
total = 0

for num in _list:
  count += 1
  total += num

print('Sum of numbers is', total)
print('Count of numbers is', count)
print('Average of numbers is', round(total/count, 2))
# Out:
# Sum of numbers is 154
# Count of numbers is 6
# Average of numbers is 25.67

# %%
for num in _list:
  if num>20:
    print('Number', num, 'is greater than 20')

print('Done')
# Out:
# Number 41 is greater than 20
# Number 74 is greater than 20
# Done

# %%
for num in _list:
  if num == 3:
    print('True', num)
  else:
    print('False', num)
# Out:
# True 3
# False 41
# False 12
# False 9
# False 74
# False 15

# %%
_list2 = [3, 41, 12, 9, 74, 15, 3]
for num in _list2:
  if num == 3:
    print('True', num)
  else:
    print('False', num)
# Out:
# True 3
# False 41
# False 12
# False 9
# False 74
# False 15
# True 3

# %%
_list3 = [3, 41, 12, 9, 74, 2, 15]
i = _list3[0]

for num in _list3:
  if num < i:
    i = num

print('Smallest number is', i)
# Out:
# Smallest number is 2

# %%
def count_adjacent_repeats(s):
  ''' (str) -> int
  Return the number of occurences of characters and an adjacent character
  being the same.
  
  >>> count_adjacent_repeats('abccdeffggh')
  3
  '''

  repeats = 0
  for i in range(len(s) - 1):
    if s[i] == s[i+1]:
      repeats += 1

  return repeats

print(count_adjacent_repeats('abccdefffggh'))
# Out:
# 4

# %%
word = 'banana'
count_a = 0
for letter in word:
  if letter == 'a':
    count_a += 1

print(count_a)
# Out:
# 3
